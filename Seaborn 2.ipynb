# %%
print('Welcome to Seaborn 2')
# Out:
# Welcome to Seaborn 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
tips = sns.load_dataset('tips')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris['species'].nunique()
# Out:
# 3

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot(data=iris,
              x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.countplot(data=tips,
              x='smoker')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
#petal_lengthand petal_width

# %%
sns.scatterplot(data=iris,
                x='petal_length',
                y='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=iris,
                x='petal_length',
                y='petal_width',
                hue='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=iris,
                x='sepal_length',
                y='sepal_width',
                hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
setosa=iris[iris['species'] == 'setosa']
versicolor=iris[iris['species'] == 'versicolor']
virginica=iris[iris['species'] == 'virginica']
plt.scatter(x=setosa['petal_length'], y=setosa['petal_width'],c='r')
plt.scatter(x=versicolor['petal_length'], y=versicolor['petal_width'],c='g')
plt.scatter(x=virginica['petal_length'], y=virginica['petal_width'],c='b')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
# 2 variables 2 plots in 1 plot

# %%
sns.jointplot(data=iris,
             x='petal_length',
             y='petal_width')

# %%
sns.jointplot(data=iris,
             x='petal_length',
             y='petal_width',
             hue='species')

# %%
# hue with regression is not possible, so it error out

# %%
sns.jointplot(data=iris,
             x='petal_length',
             y='petal_width',
             kind='reg')

# %%
sns.jointplot(data=iris,
             x='petal_length',
             y='petal_width',
             kind='hist')

# %%
sns.jointplot(data=iris,
             x='petal_length',
             y='petal_width',
             kind='hist',
             hue='species')

# %%
sns.jointplot(data=iris,
             x='petal_length',
             y='petal_width',
             kind='hex')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris, hue='species')

# %%
sns.pairplot(data=iris, hue='species', kind='kde') ## for experiment, generally not used

# %%
sns.pairplot(data=iris, hue='species', kind='hist') ## for experiment, generally not used

# %%
# c = species
# n = petal_width

# %%
sns.boxplot(data=iris,
           x='species',
           y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
data=np.array([-10,3,4,5,6,7,9,40])

# %%
sns.boxplot(x=data)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=iris,
              x='species',
              y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=iris, x='sepal_length', y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=tips, x='sex', hue='smoker')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=tips, hue='sex', x='smoker')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=tips, hue='sex', x='smoker', dodge=False)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.barplot(data=tips,
           x='day',
           y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,
           x='day',
           y='total_bill',
           estimator=np.min)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,
           x='day',
           y='total_bill',
           estimator=np.max)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,
           x='day',
           y='total_bill', hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,
           x='day',
           y='total_bill',
           hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips,
               x='tip',
               y='total_bill',
               hue='sex')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips,
               x='tip',
               y='total_bill',
               hue='sex', 
               size='size')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>
